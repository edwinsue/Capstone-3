# %%
import pandas as pd
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('/Users/EdwinSue/Desktop/NYTTP/R_Linear Regression Models/Brazilian_Ecommerce/mastertable.csv')

# %%
df.head(4)
# Out:
#    zip_code      city state product_category_name_english  \
# 0      7787   cajamar    SP                bed_bath_table
# 1      6053    osasco    SP                 health_beauty
# 2     88115  sao jose    SC                    stationery
# 3     66812     belem    PA                     telephony
#
#   order_purchase_timestamp payment_type  payment_installments  payment_value  \
# 0               2018-05-10  credit_card                     8         141.90
# 1               2018-05-07  credit_card                     1          27.19
# 2               2017-03-10  credit_card                     8          86.22
# 3               2017-10-12  credit_card                     4          43.62
#
#    lifetime_value
# 0          141.90
# 1           27.19
# 2           86.22
# 3           43.62

# %%
formula = 'lifetime_value ~ C(state) + C(city) + payment_installments + C(product_category_name_english)'

fitted_model = smf.ols(formula=formula, data=df).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         lifetime_value   R-squared:                       0.191
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     6.246
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        20:20:47   Log-Likelihood:            -7.9442e+05
# No. Observations:              115142   AIC:                         1.597e+06
# Df Residuals:                  110951   BIC:                         1.638e+06
# Df Model:                        4190
# Covariance Type:            nonrobust
# ...
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...
